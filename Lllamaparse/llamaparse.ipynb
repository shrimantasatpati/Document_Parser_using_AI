# %% [markdown]
# ### Install necessary libraries

# %%
# %pip install llama-index -qq -U
# %pip install llama-parse -qq -U

# %%
# import os
# from dotenv import load_dotenv
# load_dotenv()

import nest_asyncio  # noqa: E402
nest_asyncio.apply()

# bring in our LLAMA_CLOUD_API_KEY
from llama_parse import LlamaParse
llamaparse_api_key = "LLAMA_CLOUD_API_KEY"

# %%
llama_parse_documents = LlamaParse(api_key=llamaparse_api_key, result_type="markdown").load_data(["./data/presentation.pptx", "./data/Uber-Q4-23-Earnings-Supplemental-Data.pdf"])
# Out:
# ...
# Parsing files: 100%|██████████| 2/2 [03:18<00:00, 99.45s/it]

# %%
llama_parse_documents
# Out:
# [Document(id_='d0087f15-52f1-496e-922f-289b2ff8c137', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# Financial Statements for 2022\n\nFINAC-43\n\n20 May 2023\n\nEC-77/Doc 5 and EC-77/INF 5(1)', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  Document(id_='960b808b-bfb4-41cc-983d-eb18e90e1a13', embedding=None, metadata={}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='# Agenda\n\n- Highlights of 2022\n- Details of 2022 elements\n- Draft Resolutions', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
# ...

# %%
print(llama_parse_documents[0])
# print(llama_parse_documents[0].text[:100])
# Out:
# # Financial Statements for 2022
#
# FINAC-43
#
# 20 May 2023
#
# EC-77/Doc 5 and EC-77/INF 5(1)

# %%
type(llama_parse_documents)
# Out:
# list

# %% [markdown]
# ### Download files and store in data folder

# %%
# wget 'https://raw.githubusercontent.com/run-llama/llama_index/main/docs/examples/data/10q/uber_10q_march_2022.pdf' -O './data/uber_10q_march_2022.pdf'
# wget "https://meetings.wmo.int/Cg-19/PublishingImages/SitePages/FINAC-43/7%20-%20EC-77-Doc%205%20Financial%20Statements%20for%202022%20(FINAC).pptx" -O './data/presentation.pptx'

import os
import requests

def download_file(url, destination):
    os.makedirs(os.path.dirname(destination), exist_ok=True)
    response = requests.get(url, stream=True)
    response.raise_for_status()
    with open(destination, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)    
    print(f"Downloaded {url} to {destination}")

# URLs and destination paths
urls = [
    {
        'url': 'https://meetings.wmo.int/Cg-19/PublishingImages/SitePages/FINAC-43/7%20-%20EC-77-Doc%205%20Financial%20Statements%20for%202022%20(FINAC).pptx',
        'destination': './data/presentation.pptx'
    }
]

# Download each file
for file_info in urls:
    download_file(file_info['url'], file_info['destination'])
# Out:
# Downloaded https://meetings.wmo.int/Cg-19/PublishingImages/SitePages/FINAC-43/7%20-%20EC-77-Doc%205%20Financial%20Statements%20for%202022%20(FINAC).pptx to ./data/presentation.pptx
